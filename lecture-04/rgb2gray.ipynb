# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img = Image.open("cap.jpg")

# %%
arr = np.array(img)

# %%
arr.shape
# Out:
# (720, 1280, 3)

# %%
red = arr[:, :, 0]
green = arr[:, :, 1]
blue = arr[:, :, 2]

# %%
plt.imshow(red, cmap="gray")

# %%
plt.imshow(green, cmap="gray")

# %%
plt.imshow(blue, cmap="gray")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F8B78574A30>

# %%
plt.figure(figsize=(20, 20))
plt.imshow(np.mean(arr, axis=2), cmap="gray")
