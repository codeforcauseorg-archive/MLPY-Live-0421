# %%
from sklearn.datasets import make_blobs 

(X, y) = make_blobs(100, n_features=2, centers=4)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
y
# Out:
# array([1, 2, 2, 1, 1, 3, 1, 3, 0, 2, 1, 2, 0, 3, 3, 0, 3, 2, 3, 3, 2, 0,
#        0, 0, 0, 2, 0, 3, 1, 2, 3, 0, 1, 1, 0, 1, 1, 2, 1, 2, 1, 0, 1, 1,
#        3, 3, 0, 3, 3, 1, 3, 2, 2, 1, 3, 2, 1, 2, 0, 1, 0, 3, 2, 3, 1, 3,
#        2, 1, 3, 1, 0, 2, 0, 2, 2, 0, 0, 3, 1, 0, 1, 3, 2, 2, 0, 2, 1, 0,
#        3, 1, 2, 0, 0, 3, 0, 0, 2, 3, 3, 2])

# %%
items = [10, 20, 30]

# %%
[item+5 for item in items]
# Out:
# [15, 25, 35]

# %%
colorsDict = {
    0: "red",
    1: "blue",
    2: "yellow",
    3: "green"
}

# %%
colors = [colorsDict[item] for item in y]

# %%
plt.scatter(X[:, 0], X[:, 1], c=colors)
