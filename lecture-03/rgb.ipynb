# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
rgb = Image.open("rgb.jpg")

# %%
rgb
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=806x453 at 0x7F78E2EC7670>

# %%
imarr = np.array(rgb)

# %%
imarr[:, :, [0, 1]] = 0

# %%
plt.imshow(imarr)

# %%
imarr[0, 0]
# Out:
# array([ 72, 131,   0], dtype=uint8)
